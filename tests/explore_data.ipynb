# %%
import polars as pl

# %%
df_pl: pl.DataFrame = pl.read_parquet("../data/block.parquet")
df_pl_txs: pl.DataFrame = pl.read_parquet("../data/transaction.parquet")

# %%
df_pl.shape
# Out:
# (80304, 3)

# %%
df_pl_txs.shape
# Out:
# (655876, 7)

# %%
df_pl_cryo = pl.read_parquet('../data/raw/blocks/*.parquet')
df_pl_cryo_txs = pl.read_parquet('../data/raw/transactions/*.parquet')

# %%
df_pl_cryo.shape
# Out:
# (100000, 8)

# %%
df_pl_cryo_txs.shape
# Out:
# (655876, 22)
